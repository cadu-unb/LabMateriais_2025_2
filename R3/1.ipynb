# %%
a = '''
        1.4  & A & 9.63
        1.2  & A & 9.22
        1    & A & 8.80
        0.8  & A & 8.35
        0.6  & A & 7.88
        0.4  & A & 7.38
        0.2  & A & 6.91
        0    & A & 6.41
        -0.2 & A & 5.92
        -0.4 & A & 5.41
        -0.6 & A & 4.95
        -0.8 & A & 4.46
        -1.0 & A & 4.00
        -1.2 & A & 3.57
        -1.4 & A & 3.14'''
offset = 6.41

# %%
for i in a.splitlines():
    if i != "":
        c = i.split(' & ')
        d = i.split("& A &")
        # print(c)
        print(d[0]+' & '+f'{float(c[2])-offset:.2f} //'+' & '+d[1])
# Out:
#         1.4   & 3.22 // &  9.63
#         1.2   & 2.81 // &  9.22
#         1     & 2.39 // &  8.80
#         0.8   & 1.94 // &  8.35
#         0.6   & 1.47 // &  7.88
#         0.4   & 0.97 // &  7.38
#         0.2   & 0.50 // &  6.91
#         0     & 0.00 // &  6.41
#         -0.2  & -0.49 // &  5.92
#         -0.4  & -1.00 // &  5.41
#         -0.6  & -1.46 // &  4.95
#         -0.8  & -1.95 // &  4.46
#         -1.0  & -2.41 // &  4.00
#         -1.2  & -2.84 // &  3.57
#         -1.4  & -3.27 // &  3.14
